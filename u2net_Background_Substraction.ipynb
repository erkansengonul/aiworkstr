# %% [markdown]
# <a href="https://colab.research.google.com/github/erkansengonul/aiworkstr/blob/main/u2net_Background_Substraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#cd into drive and clone the repo
# %cd '/content/gdrive/MyDrive'
# !git clone https://github.com/Nkap23/background_removal_DL.git
# Out:
# /content/gdrive/MyDrive
# Cloning into 'background_removal_DL'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 86 (delta 26), reused 54 (delta 11), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %%
#importing required libraries 
from cv2 import cv2 
from PIL import Image

# %%
#for video 

# %cd '/content/gdrive/MyDrive/background_removal_DL/test_data/videos'
# !mkdir input_frames
# !mkdir output_frames 
# !mkdir u2net_results 

#CHANGE INPUT FILE EXTENSION HERE - BY DEFAULT: *.mp4
video=cv2.VideoCapture('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input/input.mp4')
fps=video.get(cv2.CAP_PROP_FPS)
count=0
flag=1
while flag:
  flag,image=video.read()
  if flag==0:
    break
  cv2.imwrite('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/'+'input'+str(count)+'.png',image)
  count=count+1

# %cd '/content/gdrive/MyDrive/background_removal_DL'
# !python u2net_video.py 

img_array=[]

for i in range(count):
  #u2netreusult
  u2netresult=cv2.imread('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/u2net_results/input'+str(i)+'.png')
  #original
  original=cv2.imread('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input'+str(i)+'.png')
  #subimage
  subimage=cv2.subtract(u2netresult,original)
  cv2.imwrite('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/output_frames/output'+str(i)+'.png',subimage)

  #subimage
  subimage=Image.open('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/output_frames/output'+str(i)+'.png')
  #original
  original=Image.open('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input'+str(i)+'.png')

  subimage=subimage.convert("RGBA")
  original=original.convert("RGBA")

  subdata=subimage.getdata()
  ogdata=original.getdata()

  newdata=[]
  for i in range(subdata.size[0]*subdata.size[1]):
    if subdata[i][0]==0 and subdata[i][1]==0 and subdata[i][2]==0:
      newdata.append((255,255,255,0))
    else:
      newdata.append(ogdata[i])
  subimage.putdata(newdata)
  subimage.save('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/output_frames/output'+str(i)+'.png',"PNG")

  final_img=cv2.imread('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/output_frames/output'+str(i)+'.png')
  ht,wd,l=final_img.shape
  sz=(wd,ht)
  img_array.append(final_img)

#CHANGE OUTPUT FILE EXTENSION HERE - BY DEFAULT: *.mp4
#outv=cv2.VideoWriter('/content/gdrive/MyDrive/background_removal_DL/test_data/videos/output/output.mp4',cv2.VideoWriter_fourcc(*'MP4V'),fps,sz)

#for i in img_array:
#  outv.write(i)
  
#outv.release()

#%cd '/content/gdrive/MyDrive/background_removal_DL/test_data/videos'
#!rm -R u2net_results
#!rm -R input_frames
#!rm -R output_frames
# Out:
# /content/gdrive/MyDrive/background_removal_DL/test_data/videos
# /content/gdrive/MyDrive/background_removal_DL
# ['/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input0.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input1.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input2.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input3.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input4.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input5.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input6.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input7.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input8.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input9.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input10.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input11.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input12.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input13.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input14.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input15.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input16.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input17.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input18.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input19.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input20.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input21.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input22.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input23.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input24.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input25.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input26.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input27.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input28.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input29.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input30.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input31.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input32.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input33.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input34.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input35.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input36.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input37.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input38.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input39.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input40.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input41.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input42.png', '/content/gdrive/MyDrive/background_removal_DL/test_data/videos/input_frames/input43.png', '/con ...
# ...load U2NET---173.6 MB
# inferencing: input0.png
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3487: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# inferencing: input1.png
# inferencing: input2.png
# inferencing: input3.png
# inferencing: input4.png
# inferencing: input5.png
# inferencing: input6.png
# inferencing: input7.png
# inferencing: input8.png
# inferencing: input9.png
# inferencing: input10.png
# inferencing: input11.png
# inferencing: input12.png
# inferencing: input13.png
# inferencing: input14.png
# inferencing: input15.png
# inferencing: input16.png
# inferencing: input17.png
# inferencing: input18.png
# inferencing: input19.png
# inferencing: input20.png
# inferencing: input21.png
# inferencing: input22.png
# inferencing: input23.png
# inferencing: input24.png
# inferencing: input25.png
# inferencing: input26.png
# inferencing: input27.png
# inferencing: input28.png
# inferencing: input29.png
# inferencing: input30.png
# inferencing: input31.png
# inferencing: input32.png
# inferencing: input33.png
# inferencing: input34.png
# inferencing: input35.png
# inferencing: input36.png
# inferencing: input37.png
# inferencing: input38.png
# inferencing: input39.png
# inferencing: input40.png
# inferencing: input41.png
# inferencing: input42.png
# inferencing: input43.png
# inferencing: input44.png
# inferencing: input45.png
# inferencing: input46.png
# inferencing: input47.png
# inferencing: input48.png
# inferencing: input49.png
# inferencing: input50.png
# inferencing: input51.png
# inferencing: input52.png
# inferencing: input53.png
# inferencing: input54.png
# inferencing: input55.png
# inferencing: input56.png
# inferencing: input57.png
# inferencing: input58.png
# inferencing: input59.png
# inferencing: input60.png
# inferencing: input61.png
# inferencing: input62.png
# inferencing: input63.png
# inferencing: input64.png
# inferencing: input65.png
# inferencing: input66.png
# inferencing: input67.png
# inferencing: input68.png
# inferencing: input69.png
# inferencing: input70.png
# inferencing: input71.png
# inferencing: input72.png
# inferencing: input73.png
# inferencing: input74.png
# inferencing: input75.png
# inferencing: input76.png
# inferencing: input77.png
# inferencing: input78.png
# inferencing: input79.png
# inferencing: input80.png
# inferencing: input81.png
# inferencing: input82.png
# inferencing: input83.png
# inferencing: input84.png
# inferencing: input85.png
# inferencing: input86.png
# inferencing: input87.png
# inferencing: input88.png
# inferencing: input89.png
# inferencing: input90.png
# inferencing: input91.png
# inferencing: input92.png
# inferencing: input93.png
# inferencing: input94.png
# inferencing: input95.png
# inferencing: input96.png
# inferencing: input97.png
# inferencing: input98.png
# inferencing: input99.png
# inferencing: input100.png
# inferencing: input101.png
# inferencing: input102.png
# inferencing: input103.png
# inferencing: input104.png
# inferencing: input105.png
# inferencing: input106.png
# inferencing: input107.png
# inferencing: input108.png
# inferencing: input109.png
# inferencing: input110.png
# inferencing: input111.png
# inferencing: input112.png
# inferencing: input113.png
# inferencing: input114.png
# inferencing: input115.png
# inferencing: input116.png
# inferencing: input117.png
# inferencing: input118.png
# inferencing: input119.png
# inferencing: input120.png
# inferencing: input121.png
# inferencing: input122.png
# inferencing: input123.png
# inferencing: input124.png
# inferencing: input125.png
# inferencing: input126.png
# inferencing: input127.png
# inferencing: input128.png
# inferencing: input129.png
# inferencing: input130.png
# inferencing: input131.png
# inferencing: input132.png
# inferencing: input133.png
# inferencing: input134.png
# inferencing: input135.png
# inferencing: input136.png
# inferencing: input137.png
# inferencing: input138.png
# inferencing: input139.png
# inferencing: input140.png
# inferencing: input141.png
# inferencing: input142.png
# inferencing: input143.png
# inferencing: input144.png
# inferencing: input145.png
# inferencing: input146.png
# inferencing: input147.png
# inferencing: input148.png
# inferencing: input149.png
# inferencing: input150.png
# inferencing: input151.png
# inferencing: input152.png
# inferencing: input153.png
# inferencing: input154.png
# inferencing: input155.png
# inferencing: input156.png
# inferencing: input157.png
# inferencing: input158.png
# inferencing: input159.png
# inferencing: input160.png
# inferencing: input161.png
# inferencing: input162.png
# inferencing: input163.png
# inferencing: input164.png
# inferencing: input165.png
# inferencing: input166.png
# inferencing: input167.png
# inferencing: input168.png
# inferencing: input169.png
# inferencing: input170.png
# inferencing: input171.png
# inferencing: input172.png
# inferencing: input173.png
# inferencing: input174.png
# inferencing: input175.png
# inferencing: input176.png
# inferencing: input177.png
# inferencing: input178.png
# inferencing: input179.png
# inferencing: input180.png
# inferencing: input181.png
# inferencing: input182.png
# inferencing: input183.png
# inferencing: input184.png
# inferencing: input185.png
# inferencing: input186.png
# inferencing: input187.png
# inferencing: input188.png
# inferencing: input189.png
# inferencing: input190.png
# inferencing: input191.png
# inferencing: input192.png
# inferencing: input193.png
# inferencing: input194.png
# inferencing: input195.png
# inferencing: input196.png
# inferencing: input197.png
# inferencing: input198.png
# inferencing: input199.png
# inferencing: input200.png
# inferencing: input201.png
# inferencing: input202.png
# inferencing: input203.png
# inferencing: input204.png
# inferencing: input205.png
# inferencing: input206.png
# inferencing: input207.png
# inferencing: input208.png
# inferencing: input209.png
# inferencing: input210.png
# inferencing: input211.png
# inferencing: input212.png
# inferencing: input213.png
# inferencing: input214.png
# inferencing: input215.png
# inferencing: input216.png
# inferencing: input217.png
# inferencing: input218.png
# inferencing: input219.png
# inferencing: input220.png
# inferencing: input221.png
# inferencing: input222.png
# inferencing: input223.png
# inferencing: input224.png
# inferencing: input225.png
# inferencing: input226.png
# inferencing: input227.png
# inferencing: input228.png
# inferencing: input229.png
# inferencing: input230.png
# inferencing: input231.png
# inferencing: input232.png
# inferencing: input233.png
# inferencing: input234.png
# inferencing: input235.png
# inferencing: input236.png
# inferencing: input237.png
# inferencing: input238.png
# inferencing: input239.png
# inferencing: input240.png
# inferencing: input241.png
# inferencing: input242.png
# inferencing: input243.png
# inferencing: input244.png
# inferencing: input245.png
# inferencing: input246.png
# inferencing: input247.png
# inferencing: input248.png
# inferencing: input249.png
# inferencing: input250.png
# inferencing: input251.png
# inferencing: input252.png
# inferencing: input253.png
# inferencing: input254.png
# inferencing: input255.png
# inferencing: input256.png
# inferencing: input257.png
# inferencing: input258.png
# inferencing: input259.png
# inferencing: input260.png
# inferencing: input261.png
# inferencing: input262.png
# inferencing: input263.png
# inferencing: input264.png
# inferencing: input265.png
# inferencing: input266.png
# inferencing: input267.png
# inferencing: input268.png
# inferencing: input269.png
# inferencing: input270.png
# inferencing: input271.png
# inferencing: input272.png
# inferencing: input273.png
# inferencing: input274.png
# inferencing: input275.png
# inferencing: input276.png
# inferencing: input277.png
# inferencing: input278.png
# inferencing: input279.png
# inferencing: input280.png
# inferencing: input281.png
# inferencing: input282.png
# inferencing: input283.png
# inferencing: input284.png
# inferencing: input285.png
# inferencing: input286.png
# inferencing: input287.png
# inferencing: input288.png
# inferencing: input289.png
# inferencing: input290.png
# inferencing: input291.png
# inferencing: input292.png
# inferencing: input293.png
# inferencing: input294.png
# inferencing: input295.png
# inferencing: input296.png
# inferencing: input297.png
# inferencing: input298.png
# inferencing: input299.png
# inferencing: input300.png
# inferencing: input301.png
# inferencing: input302.png
# inferencing: input303.png
# inferencing: input304.png
# inferencing: input305.png
# inferencing: input306.png
# inferencing: input307.png
# inferencing: input308.png
# inferencing: input309.png
# inferencing: input310.png
# inferencing: input311.png
# inferencing: input312.png
# inferencing: input313.png
# inferencing: input314.png
# inferencing: input315.png
# inferencing: input316.png
# inferencing: input317.png
# inferencing: input318.png
# inferencing: input319.png
# inferencing: input320.png
# inferencing: input321.png
# inferencing: input322.png
# inferencing: input323.png
# inferencing: input324.png
# inferencing: input325.png
# inferencing: input326.png
# inferencing: input327.png
# inferencing: input328.png
# inferencing: input329.png
# inferencing: input330.png
# inferencing: input331.png
# inferencing: input332.png
# inferencing: input333.png
# inferencing: input334.png
# inferencing: input335.png
# inferencing: input336.png
# inferencing: input337.png
# inferencing: input338.png
# inferencing: input339.png
# inferencing: input340.png
# inferencing: input341.png
# inferencing: input342.png
# inferencing: input343.png
# inferencing: input344.png
# inferencing: input345.png
# inferencing: input346.png
# inferencing: input347.png
# inferencing: input348.png
# inferencing: input349.png
# inferencing: input350.png
# inferencing: input351.png
# inferencing: input352.png
# inferencing: input353.png
# inferencing: input354.png
# inferencing: input355.png
# inferencing: input356.png
# inferencing: input357.png
# inferencing: input358.png
# inferencing: input359.png
# inferencing: input360.png
# inferencing: input361.png
# inferencing: input362.png
# inferencing: input363.png
# inferencing: input364.png
# inferencing: input365.png
# inferencing: input366.png
# inferencing: input367.png
# inferencing: input368.png
# inferencing: input369.png
# inferencing: input370.png
# inferencing: input371.png
# inferencing: input372.png
# inferencing: input373.png
# inferencing: input374.png
# inferencing: input375.png
# inferencing: input376.png
# inferencing: input377.png
# inferencing: input378.png
# inferencing: input379.png
# inferencing: input380.png
# inferencing: input381.png
# inferencing: input382.png
# inferencing: input383.png
# inferencing: input384.png
# inferencing: input385.png
# inferencing: input386.png
# inferencing: input387.png
# inferencing: input388.png
# inferencing: input389.png
# inferencing: input390.png
# inferencing: input391.png
# inferencing: input392.png
# inferencing: input393.png
# inferencing: input394.png
# inferencing: input395.png
# inferencing: input396.png
# inferencing: input397.png
# inferencing: input398.png
# inferencing: input399.png
# inferencing: input400.png
# inferencing: input401.png
# inferencing: input402.png
# inferencing: input403.png
# inferencing: input404.png
# inferencing: input405.png
# inferencing: input406.png
# inferencing: input407.png
# inferencing: input408.png
# inferencing: input409.png
# inferencing: input410.png
# inferencing: input411.png
# inferencing: input412.png
# inferencing: input413.png
# inferencing: input414.png
# inferencing: input415.png
# inferencing: input416.png
# inferencing: input417.png
# inferencing: input418.png
# inferencing: input419.png
# inferencing: input420.png
# inferencing: input421.png
# inferencing: input422.png
# inferencing: input423.png
# inferencing: input424.png
# inferencing: input425.png
# inferencing: input426.png
# inferencing: input427.png
# inferencing: input428.png
# inferencing: input429.png
# inferencing: input430.png
# inferencing: input431.png
# inferencing: input432.png
# inferencing: input433.png
# inferencing: input434.png
# inferencing: input435.png
# inferencing: input436.png
# inferencing: input437.png
# inferencing: input438.png
# inferencing: input439.png
# inferencing: input440.png
# inferencing: input441.png
# inferencing: input442.png
# inferencing: input443.png
# inferencing: input444.png
# inferencing: input445.png
# inferencing: input446.png
# inferencing: input447.png
# inferencing: input448.png
# inferencing: input449.png
# inferencing: input450.png
# inferencing: input451.png
# inferencing: input452.png
# inferencing: input453.png
# inferencing: input454.png
# inferencing: input455.png
# inferencing: input456.png
# inferencing: input457.png
# inferencing: input458.png
# inferencing: input459.png
# inferencing: input460.png
# inferencing: input461.png
# inferencing: input462.png
# inferencing: input463.png
# inferencing: input464.png
# inferencing: input465.png
# inferencing: input466.png
# inferencing: input467.png
# inferencing: input468.png
# inferencing: input469.png
# inferencing: input470.png
# inferencing: input471.png
# inferencing: input472.png
# inferencing: input473.png
# inferencing: input474.png
# inferencing: input475.png
# inferencing: input476.png
# inferencing: input477.png
# inferencing: input478.png
# inferencing: input479.png
# inferencing: input480.png
# inferencing: input481.png
# inferencing: input482.png
# inferencing: input483.png
# inferencing: input484.png
# inferencing: input485.png
# inferencing: input486.png
# inferencing: input487.png
# inferencing: input488.png
# inferencing: input489.png
# inferencing: input490.png
# inferencing: input491.png
# inferencing: input492.png
# inferencing: input493.png
# inferencing: input494.png
# inferencing: input495.png
# inferencing: input496.png
# inferencing: input497.png
# inferencing: input498.png
# inferencing: input499.png
# inferencing: input500.png
# inferencing: input501.png
# inferencing: input502.png
# inferencing: input503.png
# inferencing: input504.png
# inferencing: input505.png
# inferencing: input506.png
# inferencing: input507.png
# inferencing: input508.png
# inferencing: input509.png
# inferencing: input510.png
# inferencing: input511.png
# inferencing: input512.png
# inferencing: input513.png
# inferencing: input514.png
# inferencing: input515.png
# inferencing: input516.png
# inferencing: input517.png
# inferencing: input518.png
# inferencing: input519.png
# inferencing: input520.png
# inferencing: input521.png
# inferencing: input522.png
# inferencing: input523.png
# inferencing: input524.png
# inferencing: input525.png
# inferencing: input526.png
# inferencing: input527.png
# inferencing: input528.png
# inferencing: input529.png
# inferencing: input530.png
# inferencing: input531.png
# inferencing: input532.png
# inferencing: input533.png
# inferencing: input534.png
# inferencing: input535.png
# inferencing: input536.png
# inferencing: input537.png
# inferencing: input538.png
# inferencing: input539.png
# inferencing: input540.png
# inferencing: input541.png
# inferencing: input542.png
# inferencing: input543.png
# inferencing: input544.png
# inferencing: input545.png
# inferencing: input546.png
# inferencing: input547.png
# inferencing: input548.png
# inferencing: input549.png
# inferencing: input550.png
# inferencing: input551.png
# inferencing: input552.png
# inferencing: input553.png
# inferencing: input554.png
# inferencing: input555.png
# inferencing: input556.png
# inferencing: input557.png
# inferencing: input558.png
# inferencing: input559.png
# inferencing: input560.png
# inferencing: input561.png
# inferencing: input562.png
# inferencing: input563.png
# inferencing: input564.png
# inferencing: input565.png
# inferencing: input566.png
# inferencing: input567.png
# inferencing: input568.png
# inferencing: input569.png
# inferencing: input570.png
# inferencing: input571.png
# inferencing: input572.png
# inferencing: input573.png
# inferencing: input574.png
# inferencing: input575.png
# inferencing: input576.png
# inferencing: input577.png
# inferencing: input578.png
# inferencing: input579.png
# inferencing: input580.png
# inferencing: input581.png
# inferencing: input582.png
# inferencing: input583.png
# inferencing: input584.png
# inferencing: input585.png
# inferencing: input586.png
# inferencing: input587.png
# inferencing: input588.png
# inferencing: input589.png
# inferencing: input590.png
# inferencing: input591.png
# inferencing: input592.png
# inferencing: input593.png
# inferencing: input594.png
# inferencing: input595.png
# inferencing: input596.png
# inferencing: input597.png
# inferencing: input598.png
# inferencing: input599.png
# inferencing: input600.png
# inferencing: input601.png
# inferencing: input602.png
# inferencing: input603.png
# inferencing: input604.png
# inferencing: input605.png
# inferencing: input606.png
# inferencing: input607.png
# inferencing: input608.png
# inferencing: input609.png
# inferencing: input610.png
# inferencing: input611.png
# inferencing: input612.png
# inferencing: input613.png
# inferencing: input614.png
# inferencing: input615.png
# inferencing: input616.png
# inferencing: input617.png
# inferencing: input618.png
# inferencing: input619.png
# inferencing: input620.png
# inferencing: input621.png
# inferencing: input622.png
# inferencing: input623.png
# inferencing: input624.png
# inferencing: input625.png
# inferencing: input626.png
# inferencing: input627.png
# inferencing: input628.png
# inferencing: input629.png
# inferencing: input630.png
# inferencing: input631.png
# inferencing: input632.png
# inferencing: input633.png
# inferencing: input634.png
# inferencing: input635.png
# inferencing: input636.png
# inferencing: input637.png
# inferencing: input638.png
# inferencing: input639.png
# inferencing: input640.png
# inferencing: input641.png
# inferencing: input642.png
# inferencing: input643.png
# inferencing: input644.png
# inferencing: input645.png
# inferencing: input646.png
# inferencing: input647.png
# inferencing: input648.png
# inferencing: input649.png
# inferencing: input650.png
# inferencing: input651.png
# inferencing: input652.png
# inferencing: input653.png
# inferencing: input654.png
# inferencing: input655.png
# inferencing: input656.png
# inferencing: input657.png
# inferencing: input658.png
# inferencing: input659.png
# inferencing: input660.png
# inferencing: input661.png
# inferencing: input662.png
# inferencing: input663.png
# inferencing: input664.png
# inferencing: input665.png
# inferencing: input666.png
# inferencing: input667.png
# inferencing: input668.png
# inferencing: input669.png
# inferencing: input670.png
# inferencing: input671.png
# inferencing: input672.png
# inferencing: input673.png
# inferencing: input674.png
# inferencing: input675.png
# inferencing: input676.png
# inferencing: input677.png
# inferencing: input678.png
# inferencing: input679.png
# inferencing: input680.png
# inferencing: input681.png
# inferencing: input682.png
# inferencing: input683.png
# inferencing: input684.png
# inferencing: input685.png
# inferencing: input686.png
# inferencing: input687.png
# inferencing: input688.png
# inferencing: input689.png
# inferencing: input690.png
# inferencing: input691.png
# inferencing: input692.png
# inferencing: input693.png
# inferencing: input694.png
# inferencing: input695.png
# inferencing: input696.png
# inferencing: input697.png
# inferencing: input698.png
# inferencing: input699.png
# inferencing: input700.png
# inferencing: input701.png
# inferencing: input702.png
# inferencing: input703.png
# inferencing: input704.png
# inferencing: input705.png
# inferencing: input706.png
# inferencing: input707.png
# inferencing: input708.png
# inferencing: input709.png
# inferencing: input710.png
# inferencing: input711.png
# inferencing: input712.png
# inferencing: input713.png
# inferencing: input714.png
# inferencing: input715.png
# inferencing: input716.png
# inferencing: input717.png
# inferencing: input718.png
# inferencing: input719.png
# inferencing: input720.png
# inferencing: input721.png
# inferencing: input722.png
# inferencing: input723.png
# inferencing: input724.png
# inferencing: input725.png
# inferencing: input726.png
# inferencing: input727.png
# inferencing: input728.png
# inferencing: input729.png
# inferencing: input730.png
# inferencing: input731.png
# inferencing: input732.png
# inferencing: input733.png
# inferencing: input734.png
# inferencing: input735.png
# inferencing: input736.png
# inferencing: input737.png
# inferencing: input738.png
# inferencing: input739.png
# inferencing: input740.png
# inferencing: input741.png
# inferencing: input742.png
# inferencing: input743.png
# inferencing: input744.png
# inferencing: input745.png
# inferencing: input746.png
# inferencing: input747.png
# inferencing: input748.png
# inferencing: input749.png
# inferencing: input750.png
# inferencing: input751.png
# inferencing: input752.png
# inferencing: input753.png
# inferencing: input754.png
# inferencing: input755.png
# inferencing: input756.png
# inferencing: input757.png
# inferencing: input758.png
# inferencing: input759.png
# inferencing: input760.png
# inferencing: input761.png
# inferencing: input762.png
# inferencing: input763.png
# inferencing: input764.png
# inferencing: input765.png
# inferencing: input766.png
# inferencing: input767.png
# inferencing: input768.png
# inferencing: input769.png
# inferencing: input770.png
# inferencing: input771.png
# inferencing: input772.png
# inferencing: input773.png
# inferencing: input774.png
# inferencing: input775.png
# inferencing: input776.png
# inferencing: input777.png
# inferencing: input778.png
# inferencing: input779.png
# inferencing: input780.png
# inferencing: input781.png
# inferencing: input782.png
# inferencing: input783.png
# inferencing: input784.png
# inferencing: input785.png
# inferencing: input786.png
# inferencing: input787.png
# inferencing: input788.png
# inferencing: input789.png
# inferencing: input790.png
# inferencing: input791.png
# inferencing: input792.png
# inferencing: input793.png
# inferencing: input794.png
# inferencing: input795.png
# inferencing: input796.png
# inferencing: input797.png
# inferencing: input798.png
# inferencing: input799.png
# inferencing: input800.png
# inferencing: input801.png
# inferencing: input802.png
# inferencing: input803.png
# inferencing: input804.png
# inferencing: input805.png
# inferencing: input806.png
# inferencing: input807.png
# inferencing: input808.png
# inferencing: input809.png
# inferencing: input810.png
# inferencing: input811.png
# inferencing: input812.png
# inferencing: input813.png
# inferencing: input814.png
# inferencing: input815.png
# inferencing: input816.png
# inferencing: input817.png
# inferencing: input818.png
# inferencing: input819.png
# inferencing: input820.png
# inferencing: input821.png
# inferencing: input822.png
# inferencing: input823.png
# inferencing: input824.png
# inferencing: input825.png
# inferencing: input826.png
# inferencing: input827.png
# inferencing: input828.png
# inferencing: input829.png
# inferencing: input830.png
# inferencing: input831.png
# inferencing: input832.png
# inferencing: input833.png
# inferencing: input834.png
# inferencing: input835.png
# inferencing: input836.png
# inferencing: input837.png
# inferencing: input838.png
# inferencing: input839.png
# inferencing: input840.png
# inferencing: input841.png
# inferencing: input842.png
# inferencing: input843.png
# inferencing: input844.png
# inferencing: input845.png
# inferencing: input846.png
# inferencing: input847.png
# inferencing: input848.png
# inferencing: input849.png
# inferencing: input850.png
# inferencing: input851.png
# inferencing: input852.png
# inferencing: input853.png
# inferencing: input854.png
# inferencing: input855.png
# inferencing: input856.png
# inferencing: input857.png
# inferencing: input858.png
# inferencing: input859.png
# inferencing: input860.png
# inferencing: input861.png
# inferencing: input862.png
# inferencing: input863.png
# inferencing: input864.png
# inferencing: input865.png
# inferencing: input866.png
# inferencing: input867.png
# inferencing: input868.png
# inferencing: input869.png
# inferencing: input870.png
# inferencing: input871.png
# inferencing: input872.png
# inferencing: input873.png
# inferencing: input874.png
# inferencing: input875.png
# inferencing: input876.png
# inferencing: input877.png
# inferencing: input878.png
# inferencing: input879.png
# inferencing: input880.png
# inferencing: input881.png
# inferencing: input882.png
# inferencing: input883.png
# inferencing: input884.png
# inferencing: input885.png
# inferencing: input886.png
# inferencing: input887.png
# inferencing: input888.png
# inferencing: input889.png
# inferencing: input890.png
# inferencing: input891.png
# inferencing: input892.png
# inferencing: input893.png
# inferencing: input894.png
# inferencing: input895.png
# inferencing: input896.png
# inferencing: input897.png
# inferencing: input898.png
# inferencing: input899.png
# inferencing: input900.png
# inferencing: input901.png
# inferencing: input902.png
# inferencing: input903.png
# inferencing: input904.png
# inferencing: input905.png
# inferencing: input906.png
# inferencing: input907.png
# inferencing: input908.png
# inferencing: input909.png
# inferencing: input910.png
# inferencing: input911.png
# inferencing: input912.png
# inferencing: input913.png
# inferencing: input914.png
# inferencing: input915.png
# inferencing: input916.png
# inferencing: input917.png
# inferencing: input918.png
# inferencing: input919.png
# inferencing: input920.png
# inferencing: input921.png
# inferencing: input922.png
# inferencing: input923.png
# inferencing: input924.png
# inferencing: input925.png
# inferencing: input926.png
# inferencing: input927.png
# inferencing: input928.png
# inferencing: input929.png
# inferencing: input930.png
# inferencing: input931.png
# inferencing: input932.png
# inferencing: input933.png
# inferencing: input934.png
# inferencing: input935.png
# inferencing: input936.png
# inferencing: input937.png
# inferencing: input938.png
# inferencing: input939.png
# inferencing: input940.png
# inferencing: input941.png
# inferencing: input942.png
# inferencing: input943.png
# inferencing: input944.png
# inferencing: input945.png
# inferencing: input946.png
# inferencing: input947.png
# inferencing: input948.png
# inferencing: input949.png
# inferencing: input950.png
# inferencing: input951.png
# inferencing: input952.png
# inferencing: input953.png
# inferencing: input954.png
# inferencing: input955.png
# inferencing: input956.png
# inferencing: input957.png
# inferencing: input958.png
# inferencing: input959.png
# inferencing: input960.png
# inferencing: input961.png
# inferencing: input962.png
# inferencing: input963.png
# inferencing: input964.png
# inferencing: input965.png
# inferencing: input966.png
# inferencing: input967.png
# inferencing: input968.png
# inferencing: input969.png
# inferencing: input970.png
# inferencing: input971.png
# inferencing: input972.png
# inferencing: input973.png
# inferencing: input974.png
# inferencing: input975.png
# inferencing: input976.png
# inferencing: input977.png
# inferencing: input978.png
# inferencing: input979.png
# inferencing: input980.png
# inferencing: input981.png
# inferencing: input982.png
# inferencing: input983.png
# inferencing: input984.png
# inferencing: input985.png
# inferencing: input986.png
# inferencing: input987.png
# inferencing: input988.png
# inferencing: input989.png
# inferencing: input990.png
# inferencing: input991.png
# inferencing: input992.png
# inferencing: input993.png
# inferencing: input994.png
# inferencing: input995.png
# inferencing: input996.png
# inferencing: input997.png
# inferencing: input998.png
# inferencing: input999.png
# inferencing: input1000.png
# inferencing: input1001.png
# inferencing: input1002.png
# inferencing: input1003.png
# inferencing: input1004.png
# inferencing: input1005.png
# inferencing: input1006.png
# inferencing: input1007.png
# inferencing: input1008.png
# inferencing: input1009.png
# inferencing: input1010.png
# inferencing: input1011.png
# inferencing: input1012.png
# inferencing: input1013.png
# inferencing: input1014.png
# inferencing: input1015.png
# inferencing: input1016.png
# inferencing: input1017.png
# inferencing: input1018.png
# inferencing: input1019.png
# inferencing: input1020.png
# inferencing: input1021.png
# inferencing: input1022.png
# inferencing: input1023.png
# inferencing: input1024.png
# inferencing: input1025.png
# inferencing: input1026.png
# inferencing: input1027.png
# inferencing: input1028.png
# inferencing: input1029.png
# inferencing: input1030.png
# inferencing: input1031.png
# inferencing: input1032.png
# inferencing: input1033.png
# inferencing: input1034.png
# inferencing: input1035.png
# inferencing: input1036.png
# inferencing: input1037.png
# inferencing: input1038.png
# inferencing: input1039.png
# inferencing: input1040.png
# inferencing: input1041.png
# inferencing: input1042.png
# inferencing: input1043.png
# inferencing: input1044.png
# inferencing: input1045.png
# inferencing: input1046.png
# inferencing: input1047.png
# inferencing: input1048.png
# inferencing: input1049.png
# inferencing: input1050.png
# inferencing: input1051.png
# inferencing: input1052.png
# inferencing: input1053.png
# inferencing: input1054.png
# inferencing: input1055.png
# inferencing: input1056.png
# inferencing: input1057.png
# inferencing: input1058.png
# inferencing: input1059.png
# inferencing: input1060.png
# inferencing: input1061.png
# inferencing: input1062.png
# inferencing: input1063.png
# inferencing: input1064.png
# inferencing: input1065.png
# inferencing: input1066.png
# inferencing: input1067.png
# inferencing: input1068.png
# inferencing: input1069.png
# inferencing: input1070.png
# inferencing: input1071.png
# inferencing: input1072.png
# inferencing: input1073.png
# inferencing: input1074.png
# inferencing: input1075.png
# inferencing: input1076.png
# inferencing: input1077.png
# inferencing: input1078.png
# inferencing: input1079.png
# inferencing: input1080.png
# inferencing: input1081.png
# inferencing: input1082.png
# inferencing: input1083.png
# inferencing: input1084.png
# inferencing: input1085.png
# inferencing: input1086.png
# inferencing: input1087.png
# inferencing: input1088.png
# inferencing: input1089.png
# inferencing: input1090.png
# inferencing: input1091.png
# inferencing: input1092.png
# inferencing: input1093.png
# inferencing: input1094.png
# inferencing: input1095.png
# inferencing: input1096.png
# inferencing: input1097.png
# inferencing: input1098.png
# inferencing: input1099.png
# inferencing: input1100.png
# inferencing: input1101.png
# inferencing: input1102.png
# inferencing: input1103.png
# inferencing: input1104.png
# inferencing: input1105.png
# inferencing: input1106.png
# inferencing: input1107.png
# inferencing: input1108.png
# inferencing: input1109.png
# inferencing: input1110.png
# inferencing: input1111.png
# inferencing: input1112.png
# inferencing: input1113.png
# inferencing: input1114.png
# inferencing: input1115.png
# inferencing: input1116.png
# inferencing: input1117.png
# inferencing: input1118.png
# inferencing: input1119.png
# inferencing: input1120.png
# inferencing: input1121.png
# inferencing: input1122.png
# inferencing: input1123.png
# inferencing: input1124.png
# inferencing: input1125.png
# inferencing: input1126.png
# inferencing: input1127.png
# inferencing: input1128.png
# inferencing: input1129.png
# inferencing: input1130.png
# inferencing: input1131.png
# inferencing: input1132.png
# inferencing: input1133.png
# inferencing: input1134.png
# inferencing: input1135.png
# inferencing: input1136.png
# inferencing: input1137.png
# inferencing: input1138.png
# inferencing: input1139.png
# inferencing: input1140.png
# inferencing: input1141.png
# inferencing: input1142.png
# inferencing: input1143.png
# inferencing: input1144.png
# inferencing: input1145.png
# inferencing: input1146.png
# inferencing: input1147.png
# inferencing: input1148.png
# inferencing: input1149.png
# inferencing: input1150.png
# inferencing: input1151.png
# inferencing: input1152.png
# inferencing: input1153.png
# inferencing: input1154.png
# inferencing: input1155.png
# inferencing: input1156.png
# inferencing: input1157.png
# inferencing: input1158.png
# inferencing: input1159.png
# inferencing: input1160.png
# inferencing: input1161.png
# inferencing: input1162.png
# inferencing: input1163.png
# inferencing: input1164.png
# inferencing: input1165.png
# inferencing: input1166.png
# inferencing: input1167.png
# inferencing: input1168.png
# inferencing: input1169.png
# inferencing: input1170.png
# inferencing: input1171.png
# inferencing: input1172.png
# inferencing: input1173.png
# inferencing: input1174.png
# inferencing: input1175.png
# inferencing: input1176.png
# inferencing: input1177.png
# inferencing: input1178.png
# inferencing: input1179.png
# inferencing: input1180.png
# inferencing: input1181.png
# inferencing: input1182.png
# inferencing: input1183.png
# inferencing: input1184.png
# inferencing: input1185.png
# inferencing: input1186.png
# inferencing: input1187.png
# inferencing: input1188.png
# inferencing: input1189.png
# inferencing: input1190.png
# inferencing: input1191.png
# inferencing: input1192.png
# inferencing: input1193.png
# inferencing: input1194.png
# inferencing: input1195.png
# inferencing: input1196.png
# inferencing: input1197.png
# inferencing: input1198.png
# inferencing: input1199.png
# inferencing: input1200.png
# inferencing: input1201.png
# inferencing: input1202.png
# inferencing: input1203.png
# inferencing: input1204.png
# inferencing: input1205.png
# inferencing: input1206.png
# inferencing: input1207.png
# inferencing: input1208.png
# inferencing: input1209.png
# inferencing: input1210.png
# inferencing: input1211.png
# inferencing: input1212.png
# inferencing: input1213.png
# inferencing: input1214.png
# inferencing: input1215.png
# inferencing: input1216.png
# inferencing: input1217.png
# inferencing: input1218.png
# inferencing: input1219.png
# inferencing: input1220.png
# inferencing: input1221.png
# inferencing: input1222.png
# inferencing: input1223.png
# inferencing: input1224.png
# inferencing: input1225.png
# inferencing: input1226.png
# inferencing: input1227.png
# inferencing: input1228.png
# inferencing: input1229.png
# inferencing: input1230.png
# inferencing: input1231.png
# inferencing: input1232.png
# inferencing: input1233.png
# inferencing: input1234.png
# inferencing: input1235.png
# inferencing: input1236.png
# inferencing: input1237.png
# inferencing: input1238.png
# inferencing: input1239.png
# inferencing: input1240.png
# inferencing: input1241.png
# inferencing: input1242.png
# inferencing: input1243.png
# inferencing: input1244.png
# inferencing: input1245.png
# inferencing: input1246.png
# inferencing: input1247.png
# inferencing: input1248.png
# inferencing: input1249.png
# inferencing: input1250.png
# inferencing: input1251.png
# inferencing: input1252.png
# inferencing: input1253.png
# inferencing: input1254.png
# inferencing: input1255.png
# inferencing: input1256.png
# inferencing: input1257.png
# inferencing: input1258.png
# inferencing: input1259.png
# inferencing: input1260.png
# inferencing: input1261.png
# inferencing: input1262.png
# inferencing: input1263.png
# inferencing: input1264.png
# inferencing: input1265.png
# inferencing: input1266.png
# inferencing: input1267.png
# inferencing: input1268.png
# inferencing: input1269.png
# inferencing: input1270.png
# inferencing: input1271.png
# inferencing: input1272.png
# inferencing: input1273.png
# inferencing: input1274.png
# inferencing: input1275.png
# inferencing: input1276.png
# inferencing: input1277.png
# inferencing: input1278.png
# inferencing: input1279.png
# inferencing: input1280.png
# inferencing: input1281.png
# inferencing: input1282.png
# inferencing: input1283.png
# inferencing: input1284.png
# inferencing: input1285.png
# inferencing: input1286.png
# inferencing: input1287.png
# inferencing: input1288.png
# inferencing: input1289.png
# inferencing: input1290.png
# inferencing: input1291.png
# inferencing: input1292.png
# inferencing: input1293.png
# inferencing: input1294.png
# inferencing: input1295.png
# inferencing: input1296.png
# inferencing: input1297.png
# inferencing: input1298.png
# inferencing: input1299.png
# inferencing: input1300.png
# inferencing: input1301.png
# inferencing: input1302.png
# inferencing: input1303.png
# inferencing: input1304.png
# inferencing: input1305.png
# inferencing: input1306.png
# inferencing: input1307.png
# inferencing: input1308.png
# inferencing: input1309.png
# inferencing: input1310.png
# inferencing: input1311.png
# inferencing: input1312.png
# inferencing: input1313.png
# inferencing: input1314.png
# inferencing: input1315.png
# inferencing: input1316.png
# inferencing: input1317.png
# inferencing: input1318.png
# inferencing: input1319.png
# inferencing: input1320.png
# inferencing: input1321.png
# inferencing: input1322.png
# inferencing: input1323.png
# inferencing: input1324.png
# inferencing: input1325.png
# inferencing: input1326.png
# inferencing: input1327.png
# inferencing: input1328.png
# inferencing: input1329.png
# inferencing: input1330.png
# inferencing: input1331.png
# inferencing: input1332.png
# inferencing: input1333.png
# inferencing: input1334.png
# inferencing: input1335.png
# inferencing: input1336.png
# inferencing: input1337.png
# inferencing: input1338.png
# inferencing: input1339.png
# inferencing: input1340.png
# inferencing: input1341.png
# inferencing: input1342.png
# inferencing: input1343.png
# inferencing: input1344.png
# inferencing: input1345.png
# inferencing: input1346.png
# inferencing: input1347.png
# inferencing: input1348.png
# inferencing: input1349.png
# inferencing: input1350.png
# inferencing: input1351.png
# inferencing: input1352.png
# inferencing: input1353.png
# inferencing: input1354.png
# inferencing: input1355.png
# inferencing: input1356.png
# inferencing: input1357.png
# inferencing: input1358.png
# inferencing: input1359.png
# inferencing: input1360.png
# inferencing: input1361.png
# inferencing: input1362.png
# inferencing: input1363.png
# inferencing: input1364.png
# inferencing: input1365.png
# inferencing: input1366.png
# inferencing: input1367.png
# inferencing: input1368.png
# inferencing: input1369.png
# inferencing: input1370.png
# inferencing: input1371.png
# inferencing: input1372.png
# inferencing: input1373.png
# inferencing: input1374.png
# inferencing: input1375.png
# inferencing: input1376.png
# inferencing: input1377.png
# inferencing: input1378.png
# inferencing: input1379.png
# inferencing: input1380.png
# inferencing: input1381.png
# inferencing: input1382.png
# inferencing: input1383.png
# inferencing: input1384.png
# inferencing: input1385.png
# inferencing: input1386.png
# inferencing: input1387.png
# inferencing: input1388.png
# inferencing: input1389.png
# inferencing: input1390.png
# inferencing: input1391.png
# inferencing: input1392.png
# inferencing: input1393.png
# inferencing: input1394.png
# inferencing: input1395.png
# inferencing: input1396.png
# inferencing: input1397.png
# inferencing: input1398.png
# inferencing: input1399.png
# inferencing: input1400.png
# inferencing: input1401.png
# inferencing: input1402.png
# inferencing: input1403.png
# inferencing: input1404.png
# inferencing: input1405.png
# inferencing: input1406.png
# inferencing: input1407.png
# inferencing: input1408.png
# inferencing: input1409.png
# inferencing: input1410.png
# inferencing: input1411.png
# inferencing: input1412.png
# inferencing: input1413.png
# inferencing: input1414.png
# inferencing: input1415.png
# inferencing: input1416.png
# inferencing: input1417.png
# inferencing: input1418.png
# inferencing: input1419.png
# inferencing: input1420.png
# inferencing: input1421.png
# inferencing: input1422.png
# inferencing: input1423.png
# inferencing: input1424.png
# inferencing: input1425.png
# inferencing: input1426.png
# inferencing: input1427.png
# inferencing: input1428.png
# inferencing: input1429.png
# inferencing: input1430.png
# inferencing: input1431.png
# inferencing: input1432.png
# inferencing: input1433.png
# inferencing: input1434.png
# inferencing: input1435.png
# inferencing: input1436.png
# inferencing: input1437.png
# inferencing: input1438.png
# inferencing: input1439.png
# inferencing: input1440.png
# inferencing: input1441.png
# inferencing: input1442.png
# inferencing: input1443.png
# inferencing: input1444.png
# inferencing: input1445.png
# inferencing: input1446.png
# inferencing: input1447.png
# inferencing: input1448.png
# inferencing: input1449.png
# inferencing: input1450.png
# inferencing: input1451.png
# inferencing: input1452.png
# inferencing: input1453.png
# inferencing: input1454.png
# inferencing: input1455.png
# inferencing: input1456.png
# inferencing: input1457.png
# inferencing: input1458.png
# inferencing: input1459.png
# inferencing: input1460.png
# inferencing: input1461.png
# inferencing: input1462.png
# inferencing: input1463.png
# inferencing: input1464.png
# inferencing: input1465.png
# inferencing: input1466.png
# inferencing: input1467.png
# inferencing: input1468.png
# inferencing: input1469.png
# inferencing: input1470.png
# inferencing: input1471.png
# inferencing: input1472.png
# inferencing: input1473.png
# inferencing: input1474.png
# inferencing: input1475.png
# inferencing: input1476.png
# inferencing: input1477.png
# inferencing: input1478.png
# inferencing: input1479.png
# inferencing: input1480.png
# inferencing: input1481.png
# inferencing: input1482.png
# inferencing: input1483.png
# inferencing: input1484.png
# inferencing: input1485.png
# inferencing: input1486.png
# inferencing: input1487.png
# inferencing: input1488.png
# inferencing: input1489.png
# inferencing: input1490.png
# inferencing: input1491.png
# inferencing: input1492.png
# inferencing: input1493.png
# inferencing: input1494.png
# inferencing: input1495.png
# inferencing: input1496.png
# inferencing: input1497.png
# inferencing: input1498.png
# inferencing: input1499.png
# inferencing: input1500.png
# inferencing: input1501.png
# inferencing: input1502.png
# inferencing: input1503.png
# inferencing: input1504.png
# inferencing: input1505.png
# inferencing: input1506.png
# inferencing: input1507.png
# inferencing: input1508.png
# inferencing: input1509.png
# inferencing: input1510.png
# inferencing: input1511.png
# inferencing: input1512.png
# inferencing: input1513.png
# inferencing: input1514.png
# inferencing: input1515.png
# inferencing: input1516.png
# inferencing: input1517.png
# inferencing: input1518.png
# inferencing: input1519.png
# inferencing: input1520.png
# inferencing: input1521.png
# inferencing: input1522.png
# inferencing: input1523.png
# inferencing: input1524.png
# inferencing: input1525.png
# inferencing: input1526.png
# inferencing: input1527.png
# inferencing: input1528.png
# inferencing: input1529.png
# inferencing: input1530.png
# inferencing: input1531.png
# inferencing: input1532.png
# inferencing: input1533.png
# inferencing: input1534.png
# inferencing: input1535.png
# inferencing: input1536.png
# inferencing: input1537.png
# inferencing: input1538.png
# inferencing: input1539.png
# inferencing: input1540.png
# inferencing: input1541.png
# inferencing: input1542.png
# inferencing: input1543.png
# inferencing: input1544.png
# inferencing: input1545.png
# inferencing: input1546.png
# inferencing: input1547.png
# inferencing: input1548.png
# inferencing: input1549.png
# inferencing: input1550.png
# inferencing: input1551.png
# inferencing: input1552.png
# inferencing: input1553.png
# inferencing: input1554.png
# inferencing: input1555.png
# inferencing: input1556.png
# inferencing: input1557.png
# inferencing: input1558.png
# inferencing: input1559.png
# inferencing: input1560.png
# inferencing: input1561.png
# inferencing: input1562.png
# inferencing: input1563.png
# inferencing: input1564.png
# inferencing: input1565.png
# inferencing: input1566.png
# inferencing: input1567.png
# inferencing: input1568.png
# inferencing: input1569.png
# inferencing: input1570.png
# inferencing: input1571.png
# inferencing: input1572.png
# inferencing: input1573.png
# inferencing: input1574.png
# inferencing: input1575.png
# inferencing: input1576.png
# inferencing: input1577.png
# inferencing: input1578.png
# inferencing: input1579.png
# inferencing: input1580.png
# inferencing: input1581.png
# inferencing: input1582.png
# inferencing: input1583.png
# inferencing: input1584.png
# inferencing: input1585.png
# inferencing: input1586.png
# inferencing: input1587.png
# inferencing: input1588.png
# inferencing: input1589.png
# inferencing: input1590.png
# inferencing: input1591.png
# inferencing: input1592.png
# inferencing: input1593.png
# inferencing: input1594.png
# inferencing: input1595.png
# inferencing: input1596.png
# inferencing: input1597.png
# inferencing: input1598.png
# inferencing: input1599.png
# inferencing: input1600.png
# inferencing: input1601.png
# inferencing: input1602.png
# inferencing: input1603.png
# inferencing: input1604.png
# inferencing: input1605.png
# inferencing: input1606.png
# inferencing: input1607.png
# inferencing: input1608.png
# inferencing: input1609.png
# inferencing: input1610.png
# inferencing: input1611.png
# inferencing: input1612.png
# inferencing: input1613.png
# inferencing: input1614.png
# inferencing: input1615.png
# inferencing: input1616.png
# inferencing: input1617.png
# inferencing: input1618.png
# ...
# inferencing: input3002.png
# inferencing: input3003.png
# inferencing: input3004.png
# inferencing: input3005.png
# inferencing: input3006.png
# inferencing: input3007.png
# inferencing: input3008.png
# inferencing: input3009.png
# inferencing: input3010.png
# inferencing: input3011.png
# inferencing: input3012.png
# inferencing: input3013.png
# inferencing: input3014.png
# inferencing: input3015.png
# inferencing: input3016.png
# inferencing: input3017.png
# inferencing: input3018.png
# inferencing: input3019.png
# inferencing: input3020.png
# inferencing: input3021.png
# inferencing: input3022.png
# inferencing: input3023.png
# inferencing: input3024.png
# inferencing: input3025.png
# inferencing: input3026.png
# inferencing: input3027.png
# inferencing: input3028.png
# inferencing: input3029.png
# inferencing: input3030.png
# inferencing: input3031.png
# inferencing: input3032.png
# inferencing: input3033.png
# inferencing: input3034.png
# inferencing: input3035.png
# inferencing: input3036.png
# inferencing: input3037.png
# inferencing: input3038.png
# inferencing: input3039.png
# inferencing: input3040.png
# inferencing: input3041.png
# inferencing: input3042.png
# inferencing: input3043.png
# inferencing: input3044.png
# inferencing: input3045.png
# inferencing: input3046.png
# inferencing: input3047.png
# inferencing: input3048.png
# inferencing: input3049.png
# inferencing: input3050.png
# inferencing: input3051.png
# inferencing: input3052.png
# inferencing: input3053.png
# inferencing: input3054.png
# inferencing: input3055.png
# inferencing: input3056.png
# inferencing: input3057.png
# inferencing: input3058.png
# inferencing: input3059.png
# inferencing: input3060.png
# inferencing: input3061.png
# inferencing: input3062.png
# inferencing: input3063.png
# inferencing: input3064.png
# inferencing: input3065.png
# inferencing: input3066.png
# inferencing: input3067.png
# inferencing: input3068.png
# inferencing: input3069.png
# inferencing: input3070.png
# inferencing: input3071.png
# inferencing: input3072.png
# inferencing: input3073.png
# inferencing: input3074.png
# inferencing: input3075.png
# inferencing: input3076.png
# inferencing: input3077.png
# inferencing: input3078.png
# inferencing: input3079.png
# inferencing: input3080.png
# inferencing: input3081.png
# inferencing: input3082.png
# inferencing: input3083.png
# inferencing: input3084.png
# inferencing: input3085.png
# inferencing: input3086.png
# inferencing: input3087.png
# inferencing: input3088.png
# inferencing: input3089.png
# inferencing: input3090.png
# inferencing: input3091.png
# inferencing: input3092.png
# inferencing: input3093.png
# inferencing: input3094.png
# inferencing: input3095.png
# inferencing: input3096.png
# inferencing: input3097.png
# inferencing: input3098.png
# inferencing: input3099.png
# inferencing: input3100.png
# inferencing: input3101.png
# inferencing: input3102.png
# inferencing: input3103.png
# inferencing: input3104.png
# inferencing: input3105.png
# inferencing: input3106.png
# inferencing: input3107.png
# inferencing: input3108.png
# inferencing: input3109.png
# inferencing: input3110.png
# inferencing: input3111.png
# inferencing: input3112.png
# inferencing: input3113.png
# inferencing: input3114.png
# inferencing: input3115.png
# inferencing: input3116.png
# inferencing: input3117.png
# inferencing: input3118.png
# inferencing: input3119.png
# inferencing: input3120.png
# inferencing: input3121.png
# inferencing: input3122.png
# inferencing: input3123.png
# inferencing: input3124.png
# inferencing: input3125.png
# inferencing: input3126.png
# inferencing: input3127.png
# inferencing: input3128.png
# inferencing: input3129.png
# inferencing: input3130.png
# inferencing: input3131.png
# inferencing: input3132.png
# inferencing: input3133.png
# inferencing: input3134.png
# inferencing: input3135.png
# inferencing: input3136.png
# inferencing: input3137.png
# inferencing: input3138.png
# inferencing: input3139.png
# inferencing: input3140.png
# inferencing: input3141.png
# inferencing: input3142.png
# inferencing: input3143.png
# inferencing: input3144.png
# inferencing: input3145.png
# inferencing: input3146.png
# inferencing: input3147.png
# inferencing: input3148.png
# inferencing: input3149.png
# inferencing: input3150.png
# inferencing: input3151.png
# inferencing: input3152.png
# inferencing: input3153.png
# inferencing: input3154.png
# inferencing: input3155.png
# inferencing: input3156.png
# inferencing: input3157.png
# inferencing: input3158.png
# inferencing: input3159.png
# inferencing: input3160.png
# inferencing: input3161.png
# inferencing: input3162.png
# inferencing: input3163.png
# inferencing: input3164.png
# inferencing: input3165.png
# inferencing: input3166.png
# inferencing: input3167.png
# inferencing: input3168.png
# inferencing: input3169.png
# inferencing: input3170.png
# inferencing: input3171.png
# inferencing: input3172.png
# inferencing: input3173.png
# inferencing: input3174.png
# inferencing: input3175.png
# inferencing: input3176.png
# inferencing: input3177.png
# inferencing: input3178.png
# inferencing: input3179.png
# inferencing: input3180.png
# inferencing: input3181.png
# inferencing: input3182.png
# inferencing: input3183.png
# inferencing: input3184.png
# inferencing: input3185.png
# inferencing: input3186.png
# inferencing: input3187.png
# inferencing: input3188.png
# inferencing: input3189.png
# inferencing: input3190.png
# inferencing: input3191.png
# inferencing: input3192.png
# inferencing: input3193.png
# inferencing: input3194.png
# inferencing: input3195.png
# inferencing: input3196.png
# inferencing: input3197.png
# inferencing: input3198.png
# inferencing: input3199.png
# inferencing: input3200.png
# inferencing: input3201.png
# inferencing: input3202.png
# inferencing: input3203.png
# inferencing: input3204.png
# inferencing: input3205.png
# inferencing: input3206.png
# inferencing: input3207.png
# inferencing: input3208.png
# inferencing: input3209.png
# inferencing: input3210.png
# inferencing: input3211.png
# inferencing: input3212.png
# inferencing: input3213.png
# inferencing: input3214.png
# inferencing: input3215.png
# inferencing: input3216.png
# inferencing: input3217.png
# inferencing: input3218.png
# inferencing: input3219.png
# inferencing: input3220.png
# inferencing: input3221.png
# inferencing: input3222.png
# inferencing: input3223.png
# inferencing: input3224.png
# inferencing: input3225.png
# inferencing: input3226.png
# inferencing: input3227.png
# inferencing: input3228.png
# inferencing: input3229.png
# inferencing: input3230.png
# inferencing: input3231.png
# inferencing: input3232.png
# inferencing: input3233.png
# inferencing: input3234.png
# inferencing: input3235.png
# inferencing: input3236.png
# inferencing: input3237.png
# inferencing: input3238.png
# inferencing: input3239.png
# inferencing: input3240.png
# inferencing: input3241.png
# inferencing: input3242.png
# inferencing: input3243.png
# inferencing: input3244.png
# inferencing: input3245.png
# inferencing: input3246.png
# inferencing: input3247.png
# inferencing: input3248.png
# inferencing: input3249.png
# inferencing: input3250.png
# inferencing: input3251.png
# inferencing: input3252.png
# inferencing: input3253.png
# inferencing: input3254.png
# inferencing: input3255.png
# inferencing: input3256.png
# inferencing: input3257.png
# inferencing: input3258.png
# inferencing: input3259.png
# inferencing: input3260.png
# inferencing: input3261.png
# inferencing: input3262.png
# inferencing: input3263.png
# inferencing: input3264.png
# inferencing: input3265.png
# inferencing: input3266.png
# inferencing: input3267.png
# inferencing: input3268.png
# inferencing: input3269.png
# inferencing: input3270.png
# inferencing: input3271.png
# inferencing: input3272.png
# inferencing: input3273.png
# inferencing: input3274.png
# inferencing: input3275.png
# inferencing: input3276.png
# inferencing: input3277.png
# inferencing: input3278.png
# inferencing: input3279.png
# inferencing: input3280.png
# inferencing: input3281.png
# inferencing: input3282.png
# inferencing: input3283.png
# inferencing: input3284.png
# inferencing: input3285.png
# inferencing: input3286.png
# inferencing: input3287.png
# inferencing: input3288.png
# inferencing: input3289.png
# inferencing: input3290.png
# inferencing: input3291.png
# inferencing: input3292.png
# inferencing: input3293.png
# inferencing: input3294.png
# inferencing: input3295.png
# inferencing: input3296.png
# inferencing: input3297.png
# inferencing: input3298.png
# inferencing: input3299.png
# inferencing: input3300.png
# inferencing: input3301.png
# inferencing: input3302.png
# inferencing: input3303.png
# inferencing: input3304.png
# inferencing: input3305.png
# inferencing: input3306.png
# inferencing: input3307.png
# inferencing: input3308.png
# inferencing: input3309.png
# inferencing: input3310.png
# inferencing: input3311.png
# inferencing: input3312.png
# inferencing: input3313.png
# inferencing: input3314.png
# inferencing: input3315.png
# inferencing: input3316.png
# inferencing: input3317.png
# inferencing: input3318.png
# inferencing: input3319.png
# inferencing: input3320.png
# inferencing: input3321.png
# inferencing: input3322.png
# inferencing: input3323.png
# inferencing: input3324.png
# inferencing: input3325.png
# inferencing: input3326.png
# inferencing: input3327.png
# inferencing: input3328.png
# inferencing: input3329.png
# inferencing: input3330.png
# inferencing: input3331.png
# inferencing: input3332.png
# inferencing: input3333.png
# inferencing: input3334.png
# inferencing: input3335.png
# inferencing: input3336.png
# inferencing: input3337.png
# inferencing: input3338.png
# inferencing: input3339.png
# inferencing: input3340.png
# inferencing: input3341.png
# inferencing: input3342.png
# inferencing: input3343.png
# inferencing: input3344.png
# inferencing: input3345.png
# inferencing: input3346.png
# inferencing: input3347.png
# inferencing: input3348.png
# inferencing: input3349.png
# inferencing: input3350.png
# inferencing: input3351.png
# inferencing: input3352.png
# inferencing: input3353.png
# inferencing: input3354.png
# inferencing: input3355.png
# inferencing: input3356.png
# inferencing: input3357.png
# inferencing: input3358.png
# inferencing: input3359.png
# inferencing: input3360.png
# inferencing: input3361.png
# inferencing: input3362.png
# inferencing: input3363.png
# inferencing: input3364.png
# inferencing: input3365.png
# inferencing: input3366.png
# inferencing: input3367.png
# inferencing: input3368.png
# inferencing: input3369.png
# inferencing: input3370.png
# inferencing: input3371.png
# inferencing: input3372.png
# inferencing: input3373.png
# inferencing: input3374.png
# inferencing: input3375.png
# inferencing: input3376.png
# inferencing: input3377.png
# inferencing: input3378.png
# inferencing: input3379.png
# inferencing: input3380.png
# inferencing: input3381.png
# inferencing: input3382.png
# inferencing: input3383.png
# inferencing: input3384.png
# inferencing: input3385.png
# inferencing: input3386.png
# inferencing: input3387.png
# inferencing: input3388.png
# inferencing: input3389.png
# inferencing: input3390.png
# inferencing: input3391.png
# inferencing: input3392.png
# inferencing: input3393.png
# inferencing: input3394.png
# inferencing: input3395.png
# inferencing: input3396.png
# inferencing: input3397.png
# inferencing: input3398.png
# inferencing: input3399.png
# inferencing: input3400.png
# inferencing: input3401.png
# inferencing: input3402.png
# inferencing: input3403.png
# inferencing: input3404.png
# inferencing: input3405.png
# inferencing: input3406.png
# inferencing: input3407.png
# inferencing: input3408.png
# inferencing: input3409.png
# inferencing: input3410.png
# inferencing: input3411.png
# inferencing: input3412.png
# inferencing: input3413.png
# inferencing: input3414.png
# inferencing: input3415.png
# inferencing: input3416.png
# inferencing: input3417.png
# inferencing: input3418.png
# inferencing: input3419.png
# inferencing: input3420.png
# inferencing: input3421.png
# inferencing: input3422.png
# inferencing: input3423.png
# inferencing: input3424.png
# inferencing: input3425.png
# inferencing: input3426.png
# inferencing: input3427.png
# inferencing: input3428.png
# inferencing: input3429.png
# inferencing: input3430.png
# inferencing: input3431.png
# inferencing: input3432.png
# inferencing: input3433.png
# inferencing: input3434.png
# inferencing: input3435.png
# inferencing: input3436.png
# inferencing: input3437.png
# inferencing: input3438.png
# inferencing: input3439.png
# inferencing: input3440.png
# inferencing: input3441.png
# inferencing: input3442.png
# inferencing: input3443.png
# inferencing: input3444.png
# inferencing: input3445.png
# inferencing: input3446.png
# inferencing: input3447.png
# inferencing: input3448.png
# inferencing: input3449.png
# inferencing: input3450.png
# inferencing: input3451.png
# inferencing: input3452.png
# inferencing: input3453.png
# inferencing: input3454.png
# inferencing: input3455.png
# inferencing: input3456.png
# inferencing: input3457.png
# inferencing: input3458.png
# inferencing: input3459.png
# inferencing: input3460.png
# inferencing: input3461.png
# inferencing: input3462.png
# inferencing: input3463.png
# inferencing: input3464.png
# inferencing: input3465.png
# inferencing: input3466.png
# inferencing: input3467.png
# inferencing: input3468.png
# inferencing: input3469.png
# inferencing: input3470.png
# inferencing: input3471.png
# inferencing: input3472.png
# inferencing: input3473.png
# inferencing: input3474.png
# inferencing: input3475.png
# inferencing: input3476.png
# inferencing: input3477.png
# inferencing: input3478.png
# inferencing: input3479.png
# inferencing: input3480.png
# inferencing: input3481.png
# inferencing: input3482.png
# inferencing: input3483.png
# inferencing: input3484.png
# inferencing: input3485.png
# inferencing: input3486.png
# inferencing: input3487.png
# inferencing: input3488.png
# inferencing: input3489.png
# inferencing: input3490.png
# inferencing: input3491.png
# inferencing: input3492.png
# inferencing: input3493.png
# inferencing: input3494.png
# inferencing: input3495.png
# inferencing: input3496.png
# inferencing: input3497.png
# inferencing: input3498.png
# inferencing: input3499.png
# inferencing: input3500.png
# inferencing: input3501.png
# inferencing: input3502.png
# inferencing: input3503.png
# inferencing: input3504.png
# inferencing: input3505.png
# inferencing: input3506.png
# inferencing: input3507.png
# inferencing: input3508.png
# inferencing: input3509.png
# inferencing: input3510.png
# inferencing: input3511.png
# inferencing: input3512.png
# inferencing: input3513.png
# inferencing: input3514.png
# inferencing: input3515.png
# inferencing: input3516.png
# inferencing: input3517.png
# inferencing: input3518.png
# inferencing: input3519.png
# inferencing: input3520.png
# inferencing: input3521.png
# inferencing: input3522.png
# inferencing: input3523.png
# inferencing: input3524.png
# inferencing: input3525.png
# inferencing: input3526.png
# inferencing: input3527.png
# inferencing: input3528.png
# inferencing: input3529.png
# inferencing: input3530.png
# inferencing: input3531.png
# inferencing: input3532.png
# inferencing: input3533.png
# inferencing: input3534.png
# inferencing: input3535.png
# inferencing: input3536.png
# inferencing: input3537.png
# inferencing: input3538.png
# inferencing: input3539.png
# inferencing: input3540.png
# inferencing: input3541.png
# inferencing: input3542.png
# inferencing: input3543.png
# inferencing: input3544.png
# inferencing: input3545.png
# inferencing: input3546.png
# inferencing: input3547.png
# inferencing: input3548.png
# inferencing: input3549.png
# inferencing: input3550.png
# inferencing: input3551.png
# inferencing: input3552.png
# inferencing: input3553.png
# inferencing: input3554.png
# inferencing: input3555.png
# inferencing: input3556.png
# inferencing: input3557.png
# inferencing: input3558.png
# inferencing: input3559.png
# inferencing: input3560.png
# inferencing: input3561.png
# inferencing: input3562.png
# inferencing: input3563.png
# inferencing: input3564.png
# inferencing: input3565.png
# inferencing: input3566.png
# inferencing: input3567.png
# inferencing: input3568.png
# inferencing: input3569.png
# inferencing: input3570.png
# inferencing: input3571.png
# inferencing: input3572.png
# inferencing: input3573.png
# inferencing: input3574.png
# inferencing: input3575.png
# inferencing: input3576.png
# inferencing: input3577.png
# inferencing: input3578.png
# inferencing: input3579.png
# inferencing: input3580.png
# inferencing: input3581.png
# inferencing: input3582.png
# inferencing: input3583.png
# inferencing: input3584.png
# inferencing: input3585.png
# inferencing: input3586.png
# inferencing: input3587.png
# inferencing: input3588.png
# inferencing: input3589.png
# inferencing: input3590.png
# inferencing: input3591.png
# inferencing: input3592.png
# inferencing: input3593.png
